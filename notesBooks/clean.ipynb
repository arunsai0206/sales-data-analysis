# %%
import numpy as np 
import pandas as pd

# %%
sales_persons=pd.read_csv("../data/salespersons.csv")
region=pd.read_csv("../data/regions.csv")
products=pd.read_csv("../data/products.csv")
orders=pd.read_csv("../data/orders.csv")
customers=pd.read_csv("../data/customers.csv")

# %%
print(sales_persons.head(3))
print(region.head(3))
print(products.head(3))
print(orders.head(3))
print(customers.head(3))
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
#
#     Hire_Date  Exprience  Hire_Year
# 0  2022-10-31          3       2022
# 1  2022-01-22          4       2022
# 2  2022-11-07          3       2022
#    Region_ID Region_Name  Country
# 0          1       North      USA
# 1          2       South  Germany
# 2          3        East    India
#    Product_ID Product_Name     Category Brand  Unit_Price  Cost_Price
# 0           1       Laptop  Electronics  DELL        1318        1226
# 1           2   Smartphone  Electronics    HP         787         718
# 2           3       Tablet  Electronics    HP         474         375
#    Order_ID  Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# ...

# %%
print(sales_persons.isnull().sum().sum())
print(region.isnull().sum().sum())
print(orders.isnull().sum().sum())
print(customers.isnull().sum().sum())
print(products.isnull().sum().sum())
# Out:
# 0
# 0
# 0
# 0
# 0

# %%
orders[orders.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Product_ID, Salesperson_ID, Region_ID, Units_Sold, Unit_Price, Cost_Price, Revenue, Profit, Region_Name, Country, Year, Order_Year, Product_Name, Profit_Unit, Day, Month_Name]
# Index: []

# %%
region[region.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Region_ID, Region_Name, Country]
# Index: []

# %%
sales_persons[sales_persons.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Salesperson_ID, Name, Region_ID, Email, Hire_Date, Exprience, Hire_Year]
# Index: []

# %%
customers[customers.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Customer_Name, Email, Phone, City, State, Country]
# Index: []

# %%
products[products.duplicated()]
# Out:
# Empty DataFrame
# Columns: [Product_ID, Product_Name, Category, Brand, Unit_Price, Cost_Price]
# Index: []

# %%
#orders=pd.merge(orders,region,on="Region_ID",how="left")

# %%
orders.head()
# Out:
#    Order_ID  Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001  2024-03-23           86           6              15          1
# 1     10002  2024-06-20          694           3               5          3
# 2     10003  2024-01-19          229           3               9          1
# 3     10004  2023-05-11          923           2               5          4
# 4     10005  2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
region
# Out:
#    Region_ID Region_Name  Country
# 0          1       North      USA
# 1          2       South  Germany
# 2          3        East    India
# 3          4        West  Germany

# %% [markdown]
# # cleaning of sales person

# %%
sales_persons.head()
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
# 3               4   Jeffrey          4         popebrent@tucker.com
# 4               5      Jill          3           amydavid@gmail.com
#
#     Hire_Date  Exprience  Hire_Year
# 0  2022-10-31          3       2022
# 1  2022-01-22          4       2022
# 2  2022-11-07          3       2022
# 3  2020-06-05          5       2020
# 4  2023-11-01          2       2023

# %%
sales_persons[sales_persons["Salesperson_ID"].isnull()]  #duplicate in id
# Out:
# Empty DataFrame
# Columns: [Salesperson_ID, Name, Region_ID, Email, Hire_Date, Exprience, Hire_Year]
# Index: []

# %%
sales_persons[sales_persons["Email"].duplicated()]  # duplicate in email
# Out:
# Empty DataFrame
# Columns: [Salesperson_ID, Name, Region_ID, Email, Hire_Date, Exprience, Hire_Year]
# Index: []

# %%
sales_persons.isnull().sum()  # finding null values in table
# Out:
# Salesperson_ID    0
# Name              0
# Region_ID         0
# Email             0
# Hire_Date         0
# Exprience         0
# Hire_Year         0
# dtype: int64

# %%
sales_persons["Name"]=sales_persons["Name"].str.title()

# %%
sales_persons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Salesperson_ID  20 non-null     int64
#  1   Name            20 non-null     object
#  2   Region_ID       20 non-null     int64
#  3   Email           20 non-null     object
#  4   Hire_Date       20 non-null     object
#  5   Exprience       20 non-null     int64
#  6   Hire_Year       20 non-null     int64
# dtypes: int64(4), object(3)
# memory usage: 1.2+ KB

# %%
sales_persons["Email"]=sales_persons["Email"].str.lower()  #to lower case for email

# %%
sales_persons.head(2)
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
#
#     Hire_Date  Exprience  Hire_Year
# 0  2022-10-31          3       2022
# 1  2022-01-22          4       2022

# %%
sales_persons["Hire_Date"]=pd.to_datetime(sales_persons["Hire_Date"],errors="coerce")

# %%
sales_persons.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 7 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Salesperson_ID  20 non-null     int64
#  1   Name            20 non-null     object
#  2   Region_ID       20 non-null     int64
#  3   Email           20 non-null     object
#  4   Hire_Date       20 non-null     datetime64[ns]
#  5   Exprience       20 non-null     int64
#  6   Hire_Year       20 non-null     int64
# dtypes: datetime64[ns](1), int64(4), object(2)
# memory usage: 1.2+ KB

# %%
sales_persons.head()
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
# 3               4   Jeffrey          4         popebrent@tucker.com
# 4               5      Jill          3           amydavid@gmail.com
#
#    Hire_Date  Exprience  Hire_Year
# 0 2022-10-31          3       2022
# 1 2022-01-22          4       2022
# 2 2022-11-07          3       2022
# 3 2020-06-05          5       2020
# 4 2023-11-01          2       2023

# %%
# adding column experience
from datetime import datetime
sales_persons["Exprience"]=((datetime.now()-sales_persons["Hire_Date"]).dt.days/365).round(1).astype(int)

# %%
sales_persons.head()
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
# 3               4   Jeffrey          4         popebrent@tucker.com
# 4               5      Jill          3           amydavid@gmail.com
#
#    Hire_Date  Exprience  Hire_Year
# 0 2022-10-31          3       2022
# 1 2022-01-22          4       2022
# 2 2022-11-07          3       2022
# 3 2020-06-05          5       2020
# 4 2023-11-01          2       2023

# %%
total_salespersons=sales_persons["Salesperson_ID"].nunique()
total_salespersons
# Out:
# 20

# %%
sales_by_region = sales_persons['Region_ID'].value_counts()
sales_by_region
# Out:
# Region_ID
# 1    7
# 4    5
# 3    4
# 2    4
# Name: count, dtype: int64

# %%
avg_experience = sales_persons.groupby('Region_ID')['Exprience'].mean().astype(int)
print(avg_experience)
# Out:
# Region_ID
# 1    3
# 2    4
# 3    3
# 4    3
# Name: Exprience, dtype: int64

# %%
sales_persons.to_csv("salespersons.csv",index=False)

# %%
sales_persons.describe()
# Out:
#        Salesperson_ID  Region_ID            Hire_Date  Exprience    Hire_Year
# count        20.00000  20.000000                   20  20.000000    20.000000
# mean         10.50000   2.350000  2022-05-20 06:00:00   3.300000  2021.900000
# min           1.00000   1.000000  2020-06-05 00:00:00   1.000000  2020.000000
# 25%           5.75000   1.000000  2021-10-21 12:00:00   3.000000  2021.750000
# 50%          10.50000   2.000000  2022-06-13 12:00:00   3.000000  2022.000000
# 75%          15.25000   3.250000  2023-01-04 18:00:00   4.250000  2023.000000
# max          20.00000   4.000000  2024-04-16 00:00:00   5.000000  2024.000000
# std           5.91608   1.225819                  NaN   1.174286     1.165287

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        30000 non-null  int64
#  1   Order_Date      30000 non-null  object
#  2   Customer_ID     30000 non-null  int64
#  3   Product_ID      30000 non-null  int64
#  4   Salesperson_ID  30000 non-null  int64
#  5   Region_ID       30000 non-null  int64
#  6   Units_Sold      30000 non-null  int64
#  7   Unit_Price      30000 non-null  int64
#  8   Cost_Price      30000 non-null  int64
#  9   Revenue         30000 non-null  int64
#  10  Profit          30000 non-null  int64
#  11  Region_Name     30000 non-null  object
#  12  Country         30000 non-null  object
#  13  Year            30000 non-null  int64
#  14  Order_Year      30000 non-null  int64
#  15  Product_Name    30000 non-null  object
#  16  Profit_Unit     30000 non-null  float64
# ...

# %%
orders.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders["Order_ID"].head()
# Out:
# 0    10001
# 1    10002
# 2    10003
# 3    10004
# 4    10005
# Name: Order_ID, dtype: int64

# %%
orders.head()
# Out:
#    Order_ID  Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001  2024-03-23           86           6              15          1
# 1     10002  2024-06-20          694           3               5          3
# 2     10003  2024-01-19          229           3               9          1
# 3     10004  2023-05-11          923           2               5          4
# 4     10005  2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        30000 non-null  int64
#  1   Order_Date      30000 non-null  object
#  2   Customer_ID     30000 non-null  int64
#  3   Product_ID      30000 non-null  int64
#  4   Salesperson_ID  30000 non-null  int64
#  5   Region_ID       30000 non-null  int64
#  6   Units_Sold      30000 non-null  int64
#  7   Unit_Price      30000 non-null  int64
#  8   Cost_Price      30000 non-null  int64
#  9   Revenue         30000 non-null  int64
#  10  Profit          30000 non-null  int64
#  11  Region_Name     30000 non-null  object
#  12  Country         30000 non-null  object
#  13  Year            30000 non-null  int64
#  14  Order_Year      30000 non-null  int64
#  15  Product_Name    30000 non-null  object
#  16  Profit_Unit     30000 non-null  float64
# ...

# %%
orders["Order_Date"]=pd.to_datetime(orders["Order_Date"])

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        30000 non-null  int64
#  1   Order_Date      30000 non-null  datetime64[ns]
#  2   Customer_ID     30000 non-null  int64
#  3   Product_ID      30000 non-null  int64
#  4   Salesperson_ID  30000 non-null  int64
#  5   Region_ID       30000 non-null  int64
#  6   Units_Sold      30000 non-null  int64
#  7   Unit_Price      30000 non-null  int64
#  8   Cost_Price      30000 non-null  int64
#  9   Revenue         30000 non-null  int64
#  10  Profit          30000 non-null  int64
#  11  Region_Name     30000 non-null  object
#  12  Country         30000 non-null  object
#  13  Year            30000 non-null  int64
#  14  Order_Year      30000 non-null  int64
#  15  Product_Name    30000 non-null  object
#  16  Profit_Unit     30000 non-null  float64
# ...

# %%
#|orders["profit_unit"]=orders["Profit"]/orders["Units_Sold"]

# %%
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %% [markdown]
# # orders[orders["Product_ID"]==1].count()

# %%
orders.groupby("Product_ID").count()
# Out:
#             Order_ID  Order_Date  Customer_ID  Salesperson_ID  Region_ID  \
# Product_ID
# 1               4918        4918         4918            4918       4918
# 2               5109        5109         5109            5109       5109
# 3               5049        5049         5049            5049       5049
# 4               4903        4903         4903            4903       4903
# 5               5016        5016         5016            5016       5016
# 6               5005        5005         5005            5005       5005
#
#             Units_Sold  Unit_Price  Cost_Price  Revenue  Profit  Region_Name  \
# Product_ID
# 1                 4918        4918        4918     4918    4918         4918
# 2                 5109        5109        5109     5109    5109         5109
# 3                 5049        5049        5049     5049    5049         5049
# 4                 4903        4903        4903     4903    4903         4903
# ...

# %%
Q1 = orders["Revenue"].quantile(0.25)
Q3 = orders["Revenue"].quantile(0.75)
IQR = Q3 - Q1

outliers = orders[(orders["Revenue"] < Q1 - 1.5*IQR) | (orders["Revenue"] > Q3 + 1.5*IQR)]
outliers
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Product_ID, Salesperson_ID, Region_ID, Units_Sold, Unit_Price, Cost_Price, Revenue, Profit, Region_Name, Country, Year, Order_Year, Product_Name, Profit_Unit, Day, Month_Name]
# Index: []

# %%
customers.head()
# Out:
#    Customer_ID     Customer_Name                       Email  \
# 0            1       Sophia Boyd  xcompton@randolph-ryan.com
# 1            2    Matthew Miller     lcraig@moody-greene.biz
# 2            3  Rachel Henderson       jwilliams@hotmail.com
# 3            4       Stacey Howe          preyes@hotmail.com
# 4            5    Peter Petersen           amy20@hotmail.com
#
#               Phone           City         State                Country
# 0        4806757123    Elliottport  Rhode Island                   IRAQ
# 1   +1-827-697-0409    Jeromeville      Kentucky         UNITED KINGDOM
# 2      274.883.5651  Carpenterfurt         Idaho          FRENCH GUIANA
# 3  960-478-4217x028     Curtisberg        Hawaii              VENEZUELA
# 4  001-348-688-3906   West Randall       Georgia  SAO TOME AND PRINCIPE

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
customers["Customer_ID"].count()
# Out:
# np.int64(998)

# %%
customers[["Customer_Name","Phone"]].head()
# Out:
#       Customer_Name             Phone
# 0       Sophia Boyd        4806757123
# 1    Matthew Miller   +1-827-697-0409
# 2  Rachel Henderson      274.883.5651
# 3       Stacey Howe  960-478-4217x028
# 4    Peter Petersen  001-348-688-3906

# %%
customers["Country"]=customers["Country"].str.upper()

# %%
customers.head()
# Out:
#    Customer_ID     Customer_Name                       Email  \
# 0            1       Sophia Boyd  xcompton@randolph-ryan.com
# 1            2    Matthew Miller     lcraig@moody-greene.biz
# 2            3  Rachel Henderson       jwilliams@hotmail.com
# 3            4       Stacey Howe          preyes@hotmail.com
# 4            5    Peter Petersen           amy20@hotmail.com
#
#               Phone           City         State                Country
# 0        4806757123    Elliottport  Rhode Island                   IRAQ
# 1   +1-827-697-0409    Jeromeville      Kentucky         UNITED KINGDOM
# 2      274.883.5651  Carpenterfurt         Idaho          FRENCH GUIANA
# 3  960-478-4217x028     Curtisberg        Hawaii              VENEZUELA
# 4  001-348-688-3906   West Randall       Georgia  SAO TOME AND PRINCIPE

# %%
customers.groupby("Country").count()
# Out:
#                    Customer_ID  Customer_Name  Email  Phone  City  State
# Country
# AFGHANISTAN                  2              2      2      2     2      2
# ALBANIA                      5              5      5      5     5      5
# ALGERIA                      7              7      7      7     7      7
# AMERICAN SAMOA               2              2      2      2     2      2
# ANDORRA                      4              4      4      4     4      4
# ...                        ...            ...    ...    ...   ...    ...
# VIETNAM                      4              4      4      4     4      4
# WALLIS AND FUTUNA            2              2      2      2     2      2
# WESTERN SAHARA               7              7      7      7     7      7
# YEMEN                        2              2      2      2     2      2
# ZAMBIA                       6              6      6      6     6      6
#
# [239 rows x 6 columns]

# %%
customers.tail()
# Out:
#      Customer_ID      Customer_Name                        Email  \
# 993          996     Michael Willis           shaun92@martin.com
# 994          997     Heather Rivera       susanjones@griffin.com
# 995          998   Elizabeth Bishop             abrown@yahoo.com
# 996          999  Nicholas Mcdonald  ymitchell@hampton-white.net
# 997         1000       Matthew King      wheeleranne@hotmail.com
#
#                      Phone              City          State         Country
# 993           651-599-5274        Phelpsside  West Virginia       LITHUANIA
# 994   +1-475-619-6176x5021    Port Andrewton         Hawaii      LUXEMBOURG
# 995           253-806-3190        Rachelfort       Missouri           NEPAL
# 996  +1-975-311-5243x87207       Seanborough     Washington          BHUTAN
# 997       596-243-8409x277  Port Michaelbury          Texas  NORFOLK ISLAND

# %%
customers[customers["Customer_ID"]==8]
# Out:
#    Customer_ID   Customer_Name               Email             Phone  \
# 7            8  Kimberly Huber  jmurray@davis.info  681-359-2664x869
#
#            City    State Country
# 7  Lake Theresa  Montana   QATAR

# %%
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
orders[orders["Country"]=="INDIA"].count()
# Out:
# Order_ID          7476
# Order_Date        7476
# Customer_ID       7476
# Product_ID        7476
# Salesperson_ID    7476
# Region_ID         7476
# Units_Sold        7476
# Unit_Price        7476
# Cost_Price        7476
# Revenue           7476
# Profit            7476
# Region_Name       7476
# Country           7476
# Year              7476
# Order_Year        7476
# Product_Name      7476
# Profit_Unit       7476
# Day               7476
# Month_Name        7476
# dtype: int64

# %%
orders["Country"]=orders["Country"].str.upper()

# %%
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
orders.groupby(orders["Country"]).count().head()
# Out:
#          Order_ID  Order_Date  Customer_ID  Product_ID  Salesperson_ID  \
# Country
# GERMANY     15049       15049        15049       15049           15049
# INDIA        7476        7476         7476        7476            7476
# USA          7475        7475         7475        7475            7475
#
#          Region_ID  Units_Sold  Unit_Price  Cost_Price  Revenue  Profit  \
# Country
# GERMANY      15049       15049       15049       15049    15049   15049
# INDIA         7476        7476        7476        7476     7476    7476
# USA           7475        7475        7475        7475     7475    7475
#
#          Region_Name   Year  Order_Year  Product_Name  Profit_Unit    Day  \
# Country
# GERMANY        15049  15049       15049         15049        15049  15049
# INDIA           7476   7476        7476          7476         7476   7476
# USA             7475   7475        7475          7475         7475   7475
#
#          Month_Name
# Country
# GERMANY       15049
# ...

# %%
customers.head()
# Out:
#    Customer_ID     Customer_Name                       Email  \
# 0            1       Sophia Boyd  xcompton@randolph-ryan.com
# 1            2    Matthew Miller     lcraig@moody-greene.biz
# 2            3  Rachel Henderson       jwilliams@hotmail.com
# 3            4       Stacey Howe          preyes@hotmail.com
# 4            5    Peter Petersen           amy20@hotmail.com
#
#               Phone           City         State                Country
# 0        4806757123    Elliottport  Rhode Island                   IRAQ
# 1   +1-827-697-0409    Jeromeville      Kentucky         UNITED KINGDOM
# 2      274.883.5651  Carpenterfurt         Idaho          FRENCH GUIANA
# 3  960-478-4217x028     Curtisberg        Hawaii              VENEZUELA
# 4  001-348-688-3906   West Randall       Georgia  SAO TOME AND PRINCIPE

# %%
customers.isna().sum()
# Out:
# Customer_ID      0
# Customer_Name    0
# Email            0
# Phone            0
# City             0
# State            0
# Country          0
# dtype: int64

# %%
customers["Email"]=customers["Email"].str.strip()

# %%
customers["Email"]=customers["Email"].str.lower()

# %%
customers.head()
# Out:
#    Customer_ID     Customer_Name                       Email  \
# 0            1       Sophia Boyd  xcompton@randolph-ryan.com
# 1            2    Matthew Miller     lcraig@moody-greene.biz
# 2            3  Rachel Henderson       jwilliams@hotmail.com
# 3            4       Stacey Howe          preyes@hotmail.com
# 4            5    Peter Petersen           amy20@hotmail.com
#
#               Phone           City         State                Country
# 0        4806757123    Elliottport  Rhode Island                   IRAQ
# 1   +1-827-697-0409    Jeromeville      Kentucky         UNITED KINGDOM
# 2      274.883.5651  Carpenterfurt         Idaho          FRENCH GUIANA
# 3  960-478-4217x028     Curtisberg        Hawaii              VENEZUELA
# 4  001-348-688-3906   West Randall       Georgia  SAO TOME AND PRINCIPE

# %%
import re
customers["Email"].apply(lambda x:x if pd.notnull(x) and re.match(r'^[\w\.-]+@[\w\.-]+\.\w+$',x) else None)
# Out:
# 0       xcompton@randolph-ryan.com
# 1          lcraig@moody-greene.biz
# 2            jwilliams@hotmail.com
# 3               preyes@hotmail.com
# 4                amy20@hotmail.com
#                   ...
# 993             shaun92@martin.com
# 994         susanjones@griffin.com
# 995               abrown@yahoo.com
# 996    ymitchell@hampton-white.net
# 997        wheeleranne@hotmail.com
# Name: Email, Length: 998, dtype: object

# %%
customers["Email"].isna().sum()
# Out:
# np.int64(0)

# %%
customers[customers["Email"].duplicated()]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Customer_Name, Email, Phone, City, State, Country]
# Index: []

# %%
customers=customers[customers["Email"]!="ssmith@hotmail.com"]

# %%
customers[customers["Email"]=="ssmith@hotmail.com"]
# Out:
# Empty DataFrame
# Columns: [Customer_ID, Customer_Name, Email, Phone, City, State, Country]
# Index: []

# %%
customers.duplicated().sum()
# Out:
# np.int64(0)

# %%
orders.head(15)
# Out:
#     Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0      10001 2024-03-23           86           6              15          1
# 1      10002 2024-06-20          694           3               5          3
# 2      10003 2024-01-19          229           3               9          1
# 3      10004 2023-05-11          923           2               5          4
# 4      10005 2024-09-20          154           5               1          3
# 5      10006 2024-04-16          904           6               5          3
# 6      10007 2023-06-21          548           2               5          2
# 7      10008 2024-01-10          547           6              11          3
# 8      10009 2024-10-11           79           3              12          4
# 9      10010 2023-07-31          631           6              17          1
# 10     10011 2025-04-01          458           2               4          1
# ...

# %%
customers.head()
# Out:
#    Customer_ID     Customer_Name                       Email  \
# 0            1       Sophia Boyd  xcompton@randolph-ryan.com
# 1            2    Matthew Miller     lcraig@moody-greene.biz
# 2            3  Rachel Henderson       jwilliams@hotmail.com
# 3            4       Stacey Howe          preyes@hotmail.com
# 4            5    Peter Petersen           amy20@hotmail.com
#
#               Phone           City         State                Country
# 0        4806757123    Elliottport  Rhode Island                   IRAQ
# 1   +1-827-697-0409    Jeromeville      Kentucky         UNITED KINGDOM
# 2      274.883.5651  Carpenterfurt         Idaho          FRENCH GUIANA
# 3  960-478-4217x028     Curtisberg        Hawaii              VENEZUELA
# 4  001-348-688-3906   West Randall       Georgia  SAO TOME AND PRINCIPE

# %%
region.head(10)
# Out:
#    Region_ID Region_Name  Country
# 0          1       North      USA
# 1          2       South  Germany
# 2          3        East    India
# 3          4        West  Germany

# %%
region[region["Country"].duplicated()]
# Out:
#    Region_ID Region_Name  Country
# 3          4        West  Germany

# %%
orders.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 19 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_ID        30000 non-null  int64
#  1   Order_Date      30000 non-null  datetime64[ns]
#  2   Customer_ID     30000 non-null  int64
#  3   Product_ID      30000 non-null  int64
#  4   Salesperson_ID  30000 non-null  int64
#  5   Region_ID       30000 non-null  int64
#  6   Units_Sold      30000 non-null  int64
#  7   Unit_Price      30000 non-null  int64
#  8   Cost_Price      30000 non-null  int64
#  9   Revenue         30000 non-null  int64
#  10  Profit          30000 non-null  int64
#  11  Region_Name     30000 non-null  object
#  12  Country         30000 non-null  object
#  13  Year            30000 non-null  int64
#  14  Order_Year      30000 non-null  int64
#  15  Product_Name    30000 non-null  object
#  16  Profit_Unit     30000 non-null  float64
# ...

# %%
products
# Out:
#    Product_ID Product_Name         Category    Brand  Unit_Price  Cost_Price
# 0           1       Laptop      Electronics     DELL        1318        1226
# 1           2   Smartphone      Electronics       HP         787         718
# 2           3       Tablet      Electronics       HP         474         375
# 3           4      Monitor      Electronics  SAMSUNG        1270        1216
# 4           5   Headphones      Accessories       HP         943         712
# 5           6      Printer  Office Supplies   LENOVO         489         327

# %%
Q1 = orders["Cost_Price"].quantile(0.25)
Q3 = orders["Cost_Price"].quantile(0.75)
IQR = Q3 - Q1

outliers = orders[(orders["Cost_Price"] < Q1 - 1.5*IQR) | (orders["Cost_Price"] > Q3 + 1.5*IQR)]
outliers
# Out:
# Empty DataFrame
# Columns: [Order_ID, Order_Date, Customer_ID, Product_ID, Salesperson_ID, Region_ID, Units_Sold, Unit_Price, Cost_Price, Revenue, Profit, Region_Name, Country, Year, Order_Year, Product_Name, Profit_Unit, Day, Month_Name]
# Index: []

# %%
orders["Profit"].sum()
# Out:
# np.int64(42083034)

# %%
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
orders["Order_Year"]=orders["Order_Date"].dt.year

# %%
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
#orders=orders.drop("order_Year",axis=1)

# %%
y_profit=orders.groupby("Order_Year")["Profit"].sum().reset_index()
y_profit
# Out:
#    Order_Year    Profit
# 0        2023  13574299
# 1        2024  21343026
# 2        2025   7165709

# %%
orders.groupby("Order_Year").count()
# Out:
#             Order_ID  Order_Date  Customer_ID  Product_ID  Salesperson_ID  \
# Order_Year
# 2023            9821        9821         9821        9821            9821
# 2024           15093       15093        15093       15093           15093
# 2025            5086        5086         5086        5086            5086
#
#             Region_ID  Units_Sold  Unit_Price  Cost_Price  Revenue  Profit  \
# Order_Year
# 2023             9821        9821        9821        9821     9821    9821
# 2024            15093       15093       15093       15093    15093   15093
# 2025             5086        5086        5086        5086     5086    5086
#
#             Region_Name  Country   Year  Product_Name  Profit_Unit    Day  \
# Order_Year
# 2023               9821     9821   9821          9821         9821   9821
# 2024              15093    15093  15093         15093        15093  15093
# 2025               5086     5086   5086          5086         5086   5086
#
#             Month_Name
# ...

# %%
orders[orders["Order_Year"]==2025]
# Out:
#        Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  \
# 10        10011 2025-04-01          458           2               4
# 16        10017 2025-04-11          410           2              20
# 18        10019 2025-01-09          712           3               4
# 20        10021 2025-05-04          908           1              18
# 35        10036 2025-02-08           39           4              15
# ...         ...        ...          ...         ...             ...
# 29974     39975 2025-01-05          841           4              19
# 29985     39986 2025-02-13          932           1              19
# 29989     39990 2025-03-10          235           2              12
# 29990     39991 2025-02-16          854           2               5
# 29997     39998 2025-02-20          136           1               4
#
#        Region_ID  Units_Sold  Unit_Price  Cost_Price  Revenue  Profit  \
# 10             1           7         787         570     5509    1519
# ...

# %%
orders.groupby("Region_Name").count()
# Out:
#              Order_ID  Order_Date  Customer_ID  Product_ID  Salesperson_ID  \
# Region_Name
# East             7476        7476         7476        7476            7476
# North            7475        7475         7475        7475            7475
# South            7492        7492         7492        7492            7492
# West             7557        7557         7557        7557            7557
#
#              Region_ID  Units_Sold  Unit_Price  Cost_Price  Revenue  Profit  \
# Region_Name
# East              7476        7476        7476        7476     7476    7476
# North             7475        7475        7475        7475     7475    7475
# South             7492        7492        7492        7492     7492    7492
# West              7557        7557        7557        7557     7557    7557
#
#              Country  Year  Order_Year  Product_Name  Profit_Unit   Day  \
# Region_Name
# East            7476  7476        7476          7476         7476  7476
# ...

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8, 5))  # set figure size
plt.bar(y_profit['Order_Year'], y_profit['Profit'], width=0.4)
plt.title("📊 Year-wise Profit", fontsize=14)
plt.xlabel("Year", fontsize=12)
plt.ylabel("Total Profit", fontsize=12)
plt.grid(axis='y', linestyle='--', alpha=0.6)
plt.show()
# Out:
# C:\Users\sai95\AppData\Roaming\Python\Python313\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 128202 (\N{BAR CHART}) missing from font(s) DejaVu Sans.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
plt.plot(y_profit['Order_Year'], y_profit['Profit'], marker='o')
plt.title("Year-wise Profit (Line Chart)")
plt.xlabel("Year")
plt.ylabel("Profit")
plt.grid(True)
plt.show()

# %%
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
region.head()
# Out:
#    Region_ID Region_Name  Country
# 0          1       North      USA
# 1          2       South  Germany
# 2          3        East    India
# 3          4        West  Germany

# %%
customers.head()
# Out:
#    Customer_ID     Customer_Name                       Email  \
# 0            1       Sophia Boyd  xcompton@randolph-ryan.com
# 1            2    Matthew Miller     lcraig@moody-greene.biz
# 2            3  Rachel Henderson       jwilliams@hotmail.com
# 3            4       Stacey Howe          preyes@hotmail.com
# 4            5    Peter Petersen           amy20@hotmail.com
#
#               Phone           City         State                Country
# 0        4806757123    Elliottport  Rhode Island                   IRAQ
# 1   +1-827-697-0409    Jeromeville      Kentucky         UNITED KINGDOM
# 2      274.883.5651  Carpenterfurt         Idaho          FRENCH GUIANA
# 3  960-478-4217x028     Curtisberg        Hawaii              VENEZUELA
# 4  001-348-688-3906   West Randall       Georgia  SAO TOME AND PRINCIPE

# %%
sales_persons.head()
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
# 3               4   Jeffrey          4         popebrent@tucker.com
# 4               5      Jill          3           amydavid@gmail.com
#
#    Hire_Date  Exprience  Hire_Year
# 0 2022-10-31          3       2022
# 1 2022-01-22          4       2022
# 2 2022-11-07          3       2022
# 3 2020-06-05          5       2020
# 4 2023-11-01          2       2023

# %%
products.head()
# Out:
#    Product_ID Product_Name     Category    Brand  Unit_Price  Cost_Price
# 0           1       Laptop  Electronics     DELL        1318        1226
# 1           2   Smartphone  Electronics       HP         787         718
# 2           3       Tablet  Electronics       HP         474         375
# 3           4      Monitor  Electronics  SAMSUNG        1270        1216
# 4           5   Headphones  Accessories       HP         943         712

# %%
sales_persons["Hire_Year"]=sales_persons["Hire_Date"].dt.year

# %%
#sales_persons=sales_persons.drop("Year",axis=1)

# %%
sales_persons.head()
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
# 3               4   Jeffrey          4         popebrent@tucker.com
# 4               5      Jill          3           amydavid@gmail.com
#
#    Hire_Date  Exprience  Hire_Year
# 0 2022-10-31          3       2022
# 1 2022-01-22          4       2022
# 2 2022-11-07          3       2022
# 3 2020-06-05          5       2020
# 4 2023-11-01          2       2023

# %%
orders.groupby("Product_ID").count()
# Out:
#             Order_ID  Order_Date  Customer_ID  Salesperson_ID  Region_ID  \
# Product_ID
# 1               4918        4918         4918            4918       4918
# 2               5109        5109         5109            5109       5109
# 3               5049        5049         5049            5049       5049
# 4               4903        4903         4903            4903       4903
# 5               5016        5016         5016            5016       5016
# 6               5005        5005         5005            5005       5005
#
#             Units_Sold  Unit_Price  Cost_Price  Revenue  Profit  Region_Name  \
# Product_ID
# 1                 4918        4918        4918     4918    4918         4918
# 2                 5109        5109        5109     5109    5109         5109
# 3                 5049        5049        5049     5049    5049         5049
# 4                 4903        4903        4903     4903    4903         4903
# ...

# %%
orders["Month"]=orders["Order_Date"].dt.month
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
mon=orders.groupby("Year")["Profit"].sum().reset_index()
mon
# Out:
#    Year    Profit
# 0  2023  13574299
# 1  2024  21343026
# 2  2025   7165709

# %%
plt.plot(mon["Year"],mon["Profit"],color="red",marker="o",linestyle="dotted")
plt.xlabel("Month")
plt.ylabel("Profit")
plt.grid(True)
plt.show()

# %%
sales_persons.head()
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
# 3               4   Jeffrey          4         popebrent@tucker.com
# 4               5      Jill          3           amydavid@gmail.com
#
#    Hire_Date  Exprience  Hire_Year
# 0 2022-10-31          3       2022
# 1 2022-01-22          4       2022
# 2 2022-11-07          3       2022
# 3 2020-06-05          5       2020
# 4 2023-11-01          2       2023

# %%
plt.hist(sales_persons["Exprience"])
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.boxplot( orders["Units_Sold"])
plt.show()

# %%
#orders=orders.merge(products[["Product_ID","Product_Name"]],on="Product_ID" ,how="left")
orders
# Out:
#        Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  \
# 0         10001 2024-03-23           86           6              15
# 1         10002 2024-06-20          694           3               5
# 2         10003 2024-01-19          229           3               9
# 3         10004 2023-05-11          923           2               5
# 4         10005 2024-09-20          154           5               1
# ...         ...        ...          ...         ...             ...
# 29995     39996 2024-07-20          755           5               6
# 29996     39997 2024-08-15          860           5              12
# 29997     39998 2025-02-20          136           1               4
# 29998     39999 2023-12-15          692           1              19
# 29999     40000 2024-09-29          855           4               2
#
#        Region_ID  Units_Sold  Unit_Price  Cost_Price  Revenue  Profit  \
# 0              1          11         489         366     5379    1353
# ...

# %%
cn=orders["Customer_ID"].value_counts(ascending=True)
cn
# Out:
# Customer_ID
# 896    15
# 583    15
# 203    15
# 431    16
# 836    16
#        ..
# 62     45
# 184    46
# 720    46
# 595    47
# 911    47
# Name: count, Length: 1000, dtype: int64

# %%
cnn=orders.groupby("Customer_ID")["Order_ID"].count()
cnn
# Out:
# Customer_ID
# 1       32
# 2       28
# 3       29
# 4       36
# 5       38
#         ..
# 996     28
# 997     32
# 998     36
# 999     35
# 1000    31
# Name: Order_ID, Length: 1000, dtype: int64

# %%
count=orders["Product_Name"].value_counts(ascending=False)

count
# Out:
# Product_Name
# Smartphone    5109
# Tablet        5049
# Headphones    5016
# Printer       5005
# Laptop        4918
# Monitor       4903
# Name: count, dtype: int64

# %%
plt.pie(count,labels=count.index,autopct="%1.2f",startangle=90,explode=[0.2,0,0,0,0,0])
plt.axis("equal")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
plt.bar(count.index,count)
plt.show()

# %%
orders["Profit_Unit"]=orders["profit_unit"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# File c:\Users\sai95\AppData\Local\Programs\Python\Python313\Lib\site-packages\pandas\core\indexes\base.py:3805, in Index.get_loc(self, key)
#    3804 try:
# -> 3805     return self._engine.get_loc(casted_key)
#    3806 except KeyError as err:
#
# File index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File index.pyx:196, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7081, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# File pandas\\_libs\\hashtable_class_helper.pxi:7089, in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'profit_unit'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# Cell In[116], line 1
# ...

# %%
orders.head()

# %%
orders.drop("profit_unit",axis=1)

# %%
plt.scatter(orders["Year"],orders["Units_Sold"])
plt.legend()
plt.show()
# Out:
# C:\Users\sai95\AppData\Local\Temp\ipykernel_15924\3049443717.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
products
# Out:
#    Product_ID Product_Name         Category    Brand  Unit_Price  Cost_Price
# 0           1       Laptop      Electronics     DELL        1318        1226
# 1           2   Smartphone      Electronics       HP         787         718
# 2           3       Tablet      Electronics       HP         474         375
# 3           4      Monitor      Electronics  SAMSUNG        1270        1216
# 4           5   Headphones      Accessories       HP         943         712
# 5           6      Printer  Office Supplies   LENOVO         489         327

# %%
monthly_sales=orders.groupby("Month")["Revenue"].sum().reset_index()
monthly_sales
# Out:
#     Month   Revenue
# 0       1  18004663
# 1       2  15908897
# 2       3  18203769
# 3       4  17296219
# 4       5  17518716
# 5       6  16958002
# 6       7  17832354
# 7       8  17980780
# 8       9  17720192
# 9      10  18008742
# 10     11  17593262
# 11     12  17923311

# %%
plt.plot(monthly_sales["Month"],monthly_sales["Revenue"])
plt.grid()
plt.show()

# %%
orders["Day"]=orders["Order_Date"].dt.day_name()
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
days_count=orders.groupby("Day")["Order_ID"].count().reset_index()
days_count
# Out:
#          Day  Order_ID
# 0     Friday      4256
# 1     Monday      4275
# 2   Saturday      4168
# 3     Sunday      4333
# 4   Thursday      4370
# 5    Tuesday      4360
# 6  Wednesday      4238

# %%
plt.plot(days_count["Day"],days_count["Order_ID"],color="blue",linestyle="-.",marker="o")
plt.grid()
plt.show()

# %%
days_rev=orders.groupby("Day")["Revenue"].sum().reset_index()
days_rev
# Out:
#          Day   Revenue
# 0     Friday  30103322
# 1     Monday  30416314
# 2   Saturday  29495193
# 3     Sunday  30078946
# 4   Thursday  30865102
# 5    Tuesday  30097717
# 6  Wednesday  29892313

# %%
prod_rev=orders.groupby("Product_Name")["Revenue"].sum().reset_index()
prod_rev
# Out:
#   Product_Name   Revenue
# 0   Headphones  37942548
# 1       Laptop  52167758
# 2      Monitor  49528730
# 3      Printer  19592763
# 4   Smartphone  32600688
# 5       Tablet  19116420

# %%
plt.plot(prod_rev["Product_Name"],prod_rev["Revenue"])
plt.show()

# %%
prod_profit=orders.groupby("Product_Name")["Profit"].sum().reset_index()
prod_profit
# Out:
#   Product_Name   Profit
# 0   Headphones  7020067
# 1       Laptop  6952748
# 2      Monitor  6749198
# 3      Printer  7048169
# 4   Smartphone  7219990
# 5       Tablet  7092862

# %%
plt.plot(prod_profit["Product_Name"],prod_profit["Profit"])
plt.legend()
plt.show()
# Out:
# C:\Users\sai95\AppData\Local\Temp\ipykernel_15924\3346274450.py:2: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
sales_persons.head()
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
# 3               4   Jeffrey          4         popebrent@tucker.com
# 4               5      Jill          3           amydavid@gmail.com
#
#    Hire_Date  Exprience  Hire_Year
# 0 2022-10-31          3       2022
# 1 2022-01-22          4       2022
# 2 2022-11-07          3       2022
# 3 2020-06-05          5       2020
# 4 2023-11-01          2       2023

# %%
#sales_persons=sales_persons.drop("Year",axis=1)

# %%
sales_persons.head()
# Out:
#    Salesperson_ID      Name  Region_ID                        Email  \
# 0               1  Danielle          1     bweeks@kim-hernandez.com
# 1               2     Angel          3  mariahlyons@smith-brown.com
# 2               3    Joshua          1          vgarcia@hotmail.com
# 3               4   Jeffrey          4         popebrent@tucker.com
# 4               5      Jill          3           amydavid@gmail.com
#
#    Hire_Date  Exprience  Hire_Year
# 0 2022-10-31          3       2022
# 1 2022-01-22          4       2022
# 2 2022-11-07          3       2022
# 3 2020-06-05          5       2020
# 4 2023-11-01          2       2023

# %%
products["Brand"]=products["Brand"].str.upper()

# %%
products.head()
# Out:
#    Product_ID Product_Name     Category    Brand  Unit_Price  Cost_Price
# 0           1       Laptop  Electronics     DELL        1318        1226
# 1           2   Smartphone  Electronics       HP         787         718
# 2           3       Tablet  Electronics       HP         474         375
# 3           4      Monitor  Electronics  SAMSUNG        1270        1216
# 4           5   Headphones  Accessories       HP         943         712

# %%
orders.head()
# Out:
#    Order_ID Order_Date  Customer_ID  Product_ID  Salesperson_ID  Region_ID  \
# 0     10001 2024-03-23           86           6              15          1
# 1     10002 2024-06-20          694           3               5          3
# 2     10003 2024-01-19          229           3               9          1
# 3     10004 2023-05-11          923           2               5          4
# 4     10005 2024-09-20          154           5               1          3
#
#    Units_Sold  Unit_Price  Cost_Price  Revenue  Profit Region_Name  Country  \
# 0          11         489         366     5379    1353       North      USA
# 1           7         474         327     3318    1029        East    INDIA
# 2          11         474         176     5214    3278       North      USA
# 3           1         787         682      787     105        West  GERMANY
# 4          12         943         829    11316    1368        East    INDIA
#
# ...

# %%
#orders=orders.drop("profit_unit",axis=1)

# %%
orders["Month_Name"]=pd.to_datetime(orders["Month"],format='%m').dt.month_name()

# %%
#sales_persons.to_csv("salespersons.csv", index=False)

# %%
#region.to_csv("regions.csv",index=False)

# %%
#orders.to_csv("orders.csv",index=False)

# %%
#products.to_csv("products.csv",index=False)

# %%
#customers.to_csv("customers.csv",index=False)
